# %% [markdown]
# LSTM is relatively easier than CNN to implement as we hardly need to care about the relationship among kernel size, strides, input size and output size. Just make sure the dimension of input and output is defined correctly in the network.

# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,Reshape
from keras.layers import Conv1D, MaxPooling1D
from keras.utils import np_utils
from keras.layers import LSTM, LeakyReLU
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session
from tensorflow.python.client import device_lib


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

with h5py.File(''.join(['ripple2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

# Set Hyperparameters
step_size = datas.shape[1]
units= 512
second_units = 256
batch_size = 256
nb_features = datas.shape[2]
epochs = 100
output_size=16
output_file_name='ripple2016to2021_close_LSTM_1_tanh_leaky_'

# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:,0]

# Build model
model = Sequential()
model.add(LSTM(units=units,activation='tanh', input_shape=(step_size,nb_features),return_sequences=False))
model.add(Dropout(0.6))
model.add(Dense(output_size))
model.add(LeakyReLU())
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights_LSTM/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 00001: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-01-0.00507.hdf5
# 7/7 [==============================] - 3s 377ms/step - loss: 0.0111 - val_loss: 0.0051
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00002: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-02-0.00151.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00003: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-03-0.00013.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0028 - val_loss: 1.2542e-04
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00004: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-04-0.00011.hdf5
# 7/7 [==============================] - 2s 286ms/step - loss: 0.0013 - val_loss: 1.0624e-04
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 6.9831e-04
# Epoch 00005: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-05-0.00027.hdf5
# 7/7 [==============================] - 2s 287ms/step - loss: 6.9831e-04 - val_loss: 2.7007e-04
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 6.8009e-04
# Epoch 00006: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-06-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 6.8009e-04 - val_loss: 1.6872e-05
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 5.1330e-04
# Epoch 00007: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-07-0.00001.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 5.1330e-04 - val_loss: 1.0104e-05
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 4.3738e-04
# Epoch 00008: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-08-0.00006.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 4.3738e-04 - val_loss: 6.2919e-05
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 4.0194e-04
# Epoch 00009: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-09-0.00002.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 4.0194e-04 - val_loss: 1.6461e-05
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 3.8906e-04
# Epoch 00010: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-10-0.00002.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 3.8906e-04 - val_loss: 2.2151e-05
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 3.7292e-04
# Epoch 00011: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-11-0.00006.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 3.7292e-04 - val_loss: 6.1983e-05
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 3.7142e-04
# Epoch 00012: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-12-0.00002.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 3.7142e-04 - val_loss: 1.7038e-05
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 3.5936e-04
# Epoch 00013: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-13-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 3.5936e-04 - val_loss: 1.4455e-05
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 2.9198e-04
# Epoch 00014: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-14-0.00001.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 2.9198e-04 - val_loss: 1.0900e-05
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 3.6137e-04
# Epoch 00015: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-15-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 3.6137e-04 - val_loss: 2.3622e-05
# Epoch 16/100
# 7/7 [==============================] - ETA: 0s - loss: 2.9810e-04
# Epoch 00016: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-16-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.9810e-04 - val_loss: 9.1122e-06
# Epoch 17/100
# 7/7 [==============================] - ETA: 0s - loss: 2.8606e-04
# Epoch 00017: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-17-0.00003.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 2.8606e-04 - val_loss: 2.8599e-05
# Epoch 18/100
# 7/7 [==============================] - ETA: 0s - loss: 3.0386e-04
# Epoch 00018: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-18-0.00002.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 3.0386e-04 - val_loss: 1.7005e-05
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 2.8271e-04
# Epoch 00019: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-19-0.00001.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 2.8271e-04 - val_loss: 8.1376e-06
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 2.4461e-04
# Epoch 00020: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-20-0.00005.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.4461e-04 - val_loss: 4.8690e-05
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 2.7403e-04
# Epoch 00021: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-21-0.00006.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 2.7403e-04 - val_loss: 6.0512e-05
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 2.8482e-04
# Epoch 00022: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-22-0.00005.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.8482e-04 - val_loss: 5.3221e-05
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6904e-04
# Epoch 00023: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-23-0.00002.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 2.6904e-04 - val_loss: 1.6313e-05
# Epoch 24/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3881e-04
# Epoch 00024: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-24-0.00004.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 2.3881e-04 - val_loss: 3.5852e-05
# Epoch 25/100
# 7/7 [==============================] - ETA: 0s - loss: 2.4136e-04
# Epoch 00025: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-25-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 2.4136e-04 - val_loss: 1.4979e-05
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 2.2165e-04
# Epoch 00026: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-26-0.00001.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 2.2165e-04 - val_loss: 9.9792e-06
# Epoch 27/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3311e-04
# Epoch 00027: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-27-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.3311e-04 - val_loss: 8.2974e-06
# Epoch 28/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3043e-04
# Epoch 00028: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-28-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.3043e-04 - val_loss: 2.2098e-05
# Epoch 29/100
# 7/7 [==============================] - ETA: 0s - loss: 2.1932e-04
# Epoch 00029: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-29-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 2.1932e-04 - val_loss: 1.0575e-05
# Epoch 30/100
# 7/7 [==============================] - ETA: 0s - loss: 2.2713e-04
# Epoch 00030: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-30-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.2713e-04 - val_loss: 1.9712e-05
# Epoch 31/100
# 7/7 [==============================] - ETA: 0s - loss: 2.0368e-04
# Epoch 00031: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-31-0.00003.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 2.0368e-04 - val_loss: 2.9511e-05
# Epoch 32/100
# 7/7 [==============================] - ETA: 0s - loss: 2.1072e-04
# Epoch 00032: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-32-0.00003.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.1072e-04 - val_loss: 2.5029e-05
# Epoch 33/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3669e-04
# Epoch 00033: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-33-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 2.3669e-04 - val_loss: 2.3072e-05
# Epoch 34/100
# 7/7 [==============================] - ETA: 0s - loss: 1.9475e-04
# Epoch 00034: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-34-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.9475e-04 - val_loss: 1.2327e-05
# Epoch 35/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8430e-04
# Epoch 00035: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-35-0.00001.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 1.8430e-04 - val_loss: 9.7715e-06
# Epoch 36/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8966e-04
# Epoch 00036: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-36-0.00002.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 1.8966e-04 - val_loss: 1.9459e-05
# Epoch 37/100
# 7/7 [==============================] - ETA: 0s - loss: 2.1598e-04
# Epoch 00037: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-37-0.00001.hdf5
# 7/7 [==============================] - 2s 295ms/step - loss: 2.1598e-04 - val_loss: 1.1212e-05
# Epoch 38/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7250e-04
# Epoch 00038: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-38-0.00001.hdf5
# 7/7 [==============================] - 2s 294ms/step - loss: 1.7250e-04 - val_loss: 1.0519e-05
# Epoch 39/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8407e-04
# Epoch 00039: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-39-0.00004.hdf5
# 7/7 [==============================] - 2s 307ms/step - loss: 1.8407e-04 - val_loss: 4.0729e-05
# Epoch 40/100
# 7/7 [==============================] - ETA: 0s - loss: 2.0101e-04
# Epoch 00040: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-40-0.00001.hdf5
# 7/7 [==============================] - 2s 315ms/step - loss: 2.0101e-04 - val_loss: 6.1537e-06
# Epoch 41/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6571e-04
# Epoch 00041: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-41-0.00002.hdf5
# 7/7 [==============================] - 2s 320ms/step - loss: 1.6571e-04 - val_loss: 2.0150e-05
# Epoch 42/100
# 7/7 [==============================] - ETA: 0s - loss: 2.1012e-04
# Epoch 00042: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-42-0.00001.hdf5
# 7/7 [==============================] - 2s 313ms/step - loss: 2.1012e-04 - val_loss: 6.3560e-06
# Epoch 43/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8828e-04
# Epoch 00043: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-43-0.00005.hdf5
# 7/7 [==============================] - 2s 311ms/step - loss: 1.8828e-04 - val_loss: 4.8752e-05
# Epoch 44/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8865e-04
# Epoch 00044: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-44-0.00001.hdf5
# 7/7 [==============================] - 2s 314ms/step - loss: 1.8865e-04 - val_loss: 6.2542e-06
# Epoch 45/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7304e-04
# Epoch 00045: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-45-0.00002.hdf5
# 7/7 [==============================] - 2s 312ms/step - loss: 1.7304e-04 - val_loss: 1.6132e-05
# Epoch 46/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5494e-04
# Epoch 00046: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-46-0.00001.hdf5
# 7/7 [==============================] - 2s 314ms/step - loss: 1.5494e-04 - val_loss: 1.3669e-05
# Epoch 47/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5693e-04
# Epoch 00047: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-47-0.00001.hdf5
# 7/7 [==============================] - 2s 318ms/step - loss: 1.5693e-04 - val_loss: 8.7956e-06
# Epoch 48/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6497e-04
# Epoch 00048: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-48-0.00003.hdf5
# 7/7 [==============================] - 2s 310ms/step - loss: 1.6497e-04 - val_loss: 2.8922e-05
# Epoch 49/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6817e-04
# Epoch 00049: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-49-0.00001.hdf5
# 7/7 [==============================] - 2s 313ms/step - loss: 1.6817e-04 - val_loss: 6.4390e-06
# Epoch 50/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7362e-04
# Epoch 00050: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-50-0.00001.hdf5
# 7/7 [==============================] - 2s 328ms/step - loss: 1.7362e-04 - val_loss: 1.2272e-05
# Epoch 51/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5938e-04
# Epoch 00051: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-51-0.00001.hdf5
# 7/7 [==============================] - 2s 315ms/step - loss: 1.5938e-04 - val_loss: 1.3183e-05
# Epoch 52/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4047e-04
# Epoch 00052: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-52-0.00001.hdf5
# 7/7 [==============================] - 2s 288ms/step - loss: 1.4047e-04 - val_loss: 9.7772e-06
# Epoch 53/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6566e-04
# Epoch 00053: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-53-0.00002.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 1.6566e-04 - val_loss: 1.5072e-05
# Epoch 54/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3111e-04
# Epoch 00054: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-54-0.00001.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.3111e-04 - val_loss: 8.4196e-06
# Epoch 55/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4148e-04
# Epoch 00055: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-55-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.4148e-04 - val_loss: 7.9471e-06
# Epoch 56/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3824e-04
# Epoch 00056: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-56-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.3824e-04 - val_loss: 9.5740e-06
# Epoch 57/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3826e-04
# Epoch 00057: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-57-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.3826e-04 - val_loss: 2.2608e-05
# Epoch 58/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4558e-04
# Epoch 00058: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-58-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.4558e-04 - val_loss: 1.1022e-05
# Epoch 59/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4604e-04
# Epoch 00059: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-59-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.4604e-04 - val_loss: 8.7886e-06
# Epoch 60/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5092e-04
# Epoch 00060: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-60-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.5092e-04 - val_loss: 8.5396e-06
# Epoch 61/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3751e-04
# Epoch 00061: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-61-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.3751e-04 - val_loss: 1.7772e-05
# Epoch 62/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8806e-04
# Epoch 00062: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-62-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.8806e-04 - val_loss: 1.1482e-05
# Epoch 63/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7156e-04
# Epoch 00063: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-63-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.7156e-04 - val_loss: 1.2484e-05
# Epoch 64/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6271e-04
# Epoch 00064: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-64-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.6271e-04 - val_loss: 1.5922e-05
# Epoch 65/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7534e-04
# Epoch 00065: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-65-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.7534e-04 - val_loss: 1.4555e-05
# Epoch 66/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4473e-04
# Epoch 00066: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-66-0.00002.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.4473e-04 - val_loss: 1.5013e-05
# Epoch 67/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3904e-04
# Epoch 00067: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-67-0.00001.hdf5
# 7/7 [==============================] - 2s 279ms/step - loss: 1.3904e-04 - val_loss: 6.9156e-06
# Epoch 68/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5633e-04
# Epoch 00068: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-68-0.00002.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.5633e-04 - val_loss: 2.4074e-05
# Epoch 69/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3606e-04
# Epoch 00069: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-69-0.00002.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.3606e-04 - val_loss: 1.5264e-05
# Epoch 70/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2852e-04
# Epoch 00070: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-70-0.00002.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.2852e-04 - val_loss: 1.8529e-05
# Epoch 71/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5390e-04
# Epoch 00071: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-71-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.5390e-04 - val_loss: 5.2983e-06
# Epoch 72/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2138e-04
# Epoch 00072: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-72-0.00002.hdf5
# 7/7 [==============================] - 2s 287ms/step - loss: 1.2138e-04 - val_loss: 1.7384e-05
# Epoch 73/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4390e-04
# Epoch 00073: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-73-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4390e-04 - val_loss: 1.3790e-05
# Epoch 74/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1721e-04
# Epoch 00074: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-74-0.00001.hdf5
# 7/7 [==============================] - 2s 285ms/step - loss: 1.1721e-04 - val_loss: 5.6045e-06
# Epoch 75/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4907e-04
# Epoch 00075: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-75-0.00004.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.4907e-04 - val_loss: 3.5572e-05
# Epoch 76/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4982e-04
# Epoch 00076: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-76-0.00002.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.4982e-04 - val_loss: 2.0092e-05
# Epoch 77/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4105e-04
# Epoch 00077: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-77-0.00001.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.4105e-04 - val_loss: 1.3491e-05
# Epoch 78/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4130e-04
# Epoch 00078: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-78-0.00002.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.4130e-04 - val_loss: 1.7630e-05
# Epoch 79/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3398e-04
# Epoch 00079: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-79-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.3398e-04 - val_loss: 6.6310e-06
# Epoch 80/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2153e-04
# Epoch 00080: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-80-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.2153e-04 - val_loss: 7.4871e-06
# Epoch 81/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4325e-04
# Epoch 00081: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-81-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.4325e-04 - val_loss: 5.3506e-06
# Epoch 82/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1852e-04
# Epoch 00082: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-82-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.1852e-04 - val_loss: 8.8340e-06
# Epoch 83/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1106e-04
# Epoch 00083: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-83-0.00004.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.1106e-04 - val_loss: 3.8498e-05
# Epoch 84/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5828e-04
# Epoch 00084: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-84-0.00004.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.5828e-04 - val_loss: 4.0100e-05
# Epoch 85/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4174e-04
# Epoch 00085: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-85-0.00004.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4174e-04 - val_loss: 3.8187e-05
# Epoch 86/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3000e-04
# Epoch 00086: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-86-0.00000.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.3000e-04 - val_loss: 4.7807e-06
# Epoch 87/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0628e-04
# Epoch 00087: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-87-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.0628e-04 - val_loss: 7.2136e-06
# Epoch 88/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0511e-04
# Epoch 00088: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-88-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.0511e-04 - val_loss: 7.3421e-06
# Epoch 89/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0253e-04
# Epoch 00089: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-89-0.00001.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.0253e-04 - val_loss: 1.1617e-05
# Epoch 90/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0448e-04
# Epoch 00090: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-90-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.0448e-04 - val_loss: 6.7635e-06
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 9.9093e-05
# Epoch 00091: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-91-0.00001.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 9.9093e-05 - val_loss: 5.7427e-06
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3113e-04
# Epoch 00092: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-92-0.00003.hdf5
# 7/7 [==============================] - 2s 279ms/step - loss: 1.3113e-04 - val_loss: 2.8864e-05
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3948e-04
# Epoch 00093: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-93-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.3948e-04 - val_loss: 7.1417e-06
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2167e-04
# Epoch 00094: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-94-0.00002.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.2167e-04 - val_loss: 1.8634e-05
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3249e-04
# Epoch 00095: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-95-0.00001.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.3249e-04 - val_loss: 1.4934e-05
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2555e-04
# Epoch 00096: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-96-0.00001.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.2555e-04 - val_loss: 6.8803e-06
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3763e-04
# Epoch 00097: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-97-0.00005.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.3763e-04 - val_loss: 5.0401e-05
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1294e-04
# Epoch 00098: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-98-0.00001.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.1294e-04 - val_loss: 6.1160e-06
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4132e-04
# Epoch 00099: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-99-0.00007.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.4132e-04 - val_loss: 6.9685e-05
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5144e-04
# Epoch 00100: saving model to weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-100-0.00001.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.5144e-04 - val_loss: 1.0697e-05

# %% [markdown]
# # Result Plotting

# %%
### from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
from tensorflow.compat.v1 import ConfigProto, Session
# import matplotlib
import matplotlib.pyplot as plt


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['ripple2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

scaler=MinMaxScaler()
# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,0]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true.shape

ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)
ground_true_times.shape

# Set Hyperparameters
step_size = datas.shape[1]
batch_size = 256
nb_features = datas.shape[2]
epochs = 1
output_size = 16
units = 512
second_units = 256

# Build model
model = Sequential()
model.add(LSTM(units=units,activation='tanh', input_shape=(step_size,nb_features),return_sequences=False))
#model.add(LSTM(units=second_units,activation='relu',return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(output_size))
model.add(LeakyReLU())
model.load_weights('weights_LSTM/ripple2016to2021_close_LSTM_1_tanh_leaky_-100-0.00001.hdf5')
model.compile(loss='mse', optimizer='adam')

original_datas.shape

predicted = model.predict(validation_datas)
predicted_inverted = []

# We only care about the 0 axis, close price data

scaler.fit(original_datas[:,0].reshape(-1,1))
predicted_inverted.append(scaler.inverse_transform(predicted))
print(np.array(predicted_inverted).shape)
# Get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# Since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.set_index('times').reset_index()
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times     value
# 0 2020-04-04 23:25:00  0.173207
# 1 2020-04-04 23:30:00  0.174281
# 2 2020-04-04 23:35:00  0.170580
# 3 2020-04-04 23:40:00  0.175035
# 4 2020-04-04 23:45:00  0.168902

# %%
prediction_df_load = prediction_df.loc[(prediction_df["times"].dt.year >= 2020)&(prediction_df["times"].dt.month >= 1),:]
# 
ground_true_df_load = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020)&(ground_true_df["times"].dt.month >= 1),:]
# 

plt.figure(figsize=(20,10))
plt.plot(ground_true_df_load.times,ground_true_df_load.value, label = 'Actual')
# plt.plot(prediction_df.times,prediction_df.value, label = 'Predicted')
plt.plot(prediction_df_load.times,prediction_df_load.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/ripple2016to2021_close_LSTM_1_tanh_leaky_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 0.00011473127750036399
