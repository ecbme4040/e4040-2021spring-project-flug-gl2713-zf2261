# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU, PReLU
from keras.utils import np_utils
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session


# Make the program use only one GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))
# print(tf.config.list_physical_devices('GPU'))

with h5py.File(''.join(['ethereum2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

output_file_name='ethereum2016to2021_close_CNN_2_relu'

step_size = datas.shape[1]
batch_size= 128
nb_features = datas.shape[2]

epochs = 100

#split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:]
#build model

# 2 layers
model = Sequential()

model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=16, kernel_size=32))
model.add(Dropout(0.5))
model.add(Conv1D(strides=3, filters=nb_features, kernel_size=28))

'''
# 3 Layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=8))
# 4 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=2))
'''

model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels,verbose=1, batch_size=batch_size,validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights_CNN/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00001: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-01-0.00273.hdf5
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 2/100
#  1/13 [=>............................] - ETA: 0s - loss: 0.0032
# Epoch 00002: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-02-0.00022.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 2.2269e-04
# Epoch 3/100
#  1/13 [=>............................] - ETA: 0s - loss: 0.0014
# Epoch 00003: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-03-0.00077.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 7.6730e-04
# Epoch 4/100
#  1/13 [=>............................] - ETA: 0s - loss: 9.8673e-04
# Epoch 00004: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-04-0.00073.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 9.6380e-04 - val_loss: 7.3087e-04
# Epoch 5/100
#  1/13 [=>............................] - ETA: 0s - loss: 7.4142e-04
# Epoch 00005: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-05-0.00052.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 8.6381e-04 - val_loss: 5.2179e-04
# Epoch 6/100
#  1/13 [=>............................] - ETA: 0s - loss: 8.3342e-04
# Epoch 00006: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-06-0.00052.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 7.1565e-04 - val_loss: 5.1703e-04
# Epoch 7/100
#  1/13 [=>............................] - ETA: 0s - loss: 7.4688e-04
# Epoch 00007: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-07-0.00045.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 6.5137e-04 - val_loss: 4.4846e-04
# Epoch 8/100
#  1/13 [=>............................] - ETA: 0s - loss: 5.8878e-04
# Epoch 00008: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-08-0.00029.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 6.2297e-04 - val_loss: 2.8526e-04
# Epoch 9/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.9100e-04
# Epoch 00009: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-09-0.00066.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 5.4067e-04 - val_loss: 6.6210e-04
# Epoch 10/100
#  1/13 [=>............................] - ETA: 0s - loss: 6.9198e-04
# Epoch 00010: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-10-0.00056.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 5.8952e-04 - val_loss: 5.5770e-04
# Epoch 11/100
#  1/13 [=>............................] - ETA: 0s - loss: 8.8926e-04
# Epoch 00011: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-11-0.00058.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 5.1445e-04 - val_loss: 5.7644e-04
# Epoch 12/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.8938e-04
# Epoch 00012: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-12-0.00031.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 4.6552e-04 - val_loss: 3.0944e-04
# Epoch 13/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.2681e-04
# Epoch 00013: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-13-0.00022.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 4.4836e-04 - val_loss: 2.1601e-04
# Epoch 14/100
#  1/13 [=>............................] - ETA: 0s - loss: 5.5513e-04
# Epoch 00014: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-14-0.00031.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 4.2640e-04 - val_loss: 3.1042e-04
# Epoch 15/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.8854e-04
# Epoch 00015: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-15-0.00023.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 4.1537e-04 - val_loss: 2.3273e-04
# Epoch 16/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.8237e-04
# Epoch 00016: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-16-0.00024.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.9971e-04 - val_loss: 2.3664e-04
# Epoch 17/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.5676e-04
# Epoch 00017: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-17-0.00021.hdf5
# 13/13 [==============================] - 0s 9ms/step - loss: 4.0764e-04 - val_loss: 2.1380e-04
# Epoch 18/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.9459e-04
# Epoch 00018: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-18-0.00068.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 4.0886e-04 - val_loss: 6.8396e-04
# Epoch 19/100
#  1/13 [=>............................] - ETA: 0s - loss: 6.9276e-04
# Epoch 00019: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-19-0.00033.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 4.1511e-04 - val_loss: 3.3106e-04
# Epoch 20/100
#  1/13 [=>............................] - ETA: 0s - loss: 5.2906e-04
# Epoch 00020: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-20-0.00102.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.8112e-04 - val_loss: 0.0010
# Epoch 21/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.2554e-04
# Epoch 00021: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-21-0.00087.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 4.3761e-04 - val_loss: 8.7485e-04
# Epoch 22/100
#  1/13 [=>............................] - ETA: 0s - loss: 5.0421e-04
# Epoch 00022: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-22-0.00021.hdf5
# 13/13 [==============================] - 0s 9ms/step - loss: 4.2159e-04 - val_loss: 2.0973e-04
# Epoch 23/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.7102e-04
# Epoch 00023: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-23-0.00021.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 3.7346e-04 - val_loss: 2.1104e-04
# Epoch 24/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.2244e-04
# Epoch 00024: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-24-0.00030.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.6090e-04 - val_loss: 3.0286e-04
# Epoch 25/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.6360e-04
# Epoch 00025: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-25-0.00021.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.4442e-04 - val_loss: 2.1416e-04
# Epoch 26/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.8374e-04
# Epoch 00026: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-26-0.00079.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.7002e-04 - val_loss: 7.8833e-04
# Epoch 27/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.6042e-04
# Epoch 00027: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-27-0.00098.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.3307e-04 - val_loss: 9.8449e-04
# Epoch 28/100
#  1/13 [=>............................] - ETA: 0s - loss: 5.0948e-04
# Epoch 00028: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-28-0.00022.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.7345e-04 - val_loss: 2.2177e-04
# Epoch 29/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.5608e-04
# Epoch 00029: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-29-0.00021.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.3318e-04 - val_loss: 2.1068e-04
# Epoch 30/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.1063e-04
# Epoch 00030: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-30-0.00046.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.1948e-04 - val_loss: 4.5750e-04
# Epoch 31/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.5318e-04
# Epoch 00031: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-31-0.00026.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.0669e-04 - val_loss: 2.5759e-04
# Epoch 32/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.9099e-04
# Epoch 00032: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-32-0.00038.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.2759e-04 - val_loss: 3.8404e-04
# Epoch 33/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.1753e-04
# Epoch 00033: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-33-0.00114.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.1306e-04 - val_loss: 0.0011
# Epoch 34/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.8945e-04
# Epoch 00034: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-34-0.00031.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.6591e-04 - val_loss: 3.1194e-04
# Epoch 35/100
#  1/13 [=>............................] - ETA: 0s - loss: 5.3406e-04
# Epoch 00035: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-35-0.00087.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.6051e-04 - val_loss: 8.6953e-04
# Epoch 36/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.5515e-04
# Epoch 00036: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-36-0.00036.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.6765e-04 - val_loss: 3.5647e-04
# Epoch 37/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.2335e-04
# Epoch 00037: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-37-0.00051.hdf5
# 13/13 [==============================] - 0s 9ms/step - loss: 3.1821e-04 - val_loss: 5.1109e-04
# Epoch 38/100
#  1/13 [=>............................] - ETA: 0s - loss: 2
saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-87-0.00028.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.1572e-04 - val_loss: 2.8211e-04
# Epoch 88/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.0039e-04
# Epoch 00088: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-88-0.00161.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.6666e-04 - val_loss: 0.0016
# Epoch 89/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.5251e-04
# Epoch 00089: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-89-0.00026.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.6060e-04 - val_loss: 2.5647e-04
# Epoch 90/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.5378e-04
# Epoch 00090: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-90-0.00041.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.2904e-04 - val_loss: 4.0809e-04
# Epoch 91/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.9870e-04
# Epoch 00091: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-91-0.00030.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.2605e-04 - val_loss: 2.9864e-04
# Epoch 92/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.0579e-04
# Epoch 00092: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-92-0.00032.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.2095e-04 - val_loss: 3.2062e-04
# Epoch 93/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.6382e-04
# Epoch 00093: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-93-0.00074.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.2938e-04 - val_loss: 7.4447e-04
# Epoch 94/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.1030e-04
# Epoch 00094: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-94-0.00171.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 3.7143e-04 - val_loss: 0.0017
# Epoch 95/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.4082e-04
# Epoch 00095: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-95-0.00058.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.6498e-04 - val_loss: 5.7693e-04
# Epoch 96/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.7579e-04
# Epoch 00096: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-96-0.00168.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.4675e-04 - val_loss: 0.0017
# Epoch 97/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.5303e-04
# Epoch 00097: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-97-0.00020.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.0569e-04 - val_loss: 2.0011e-04
# Epoch 98/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.4831e-04
# Epoch 00098: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-98-0.00021.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7007e-04 - val_loss: 2.1358e-04
# Epoch 99/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.0959e-04
# Epoch 00099: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-99-0.00045.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.4801e-04 - val_loss: 4.4976e-04
# Epoch 100/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.2113e-04
# Epoch 00100: saving model to weights_CNN/ethereum2016to2021_close_CNN_2_relu-100-0.00023.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.3148e-04 - val_loss: 2.3074e-04

# %% [markdown]
# # Result Plotting

# %% [markdown]
# First, we need to reconstruct the model and load the trained_weights into the model.

# %%
from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
# import matplotlib

import matplotlib.pyplot as plt

os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['ethereum2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

scaler=MinMaxScaler()
#split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,:]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,:]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)
step_size = datas.shape[1]
batch_size= 128
nb_features = datas.shape[2]

model = Sequential()

# 2 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=16, kernel_size=32))
# model.add(LeakyReLU())
model.add(Dropout(0.25))
model.add(Conv1D( strides=3, filters=nb_features, kernel_size=28))
model.load_weights('weights_CNN/ethereum2016to2021_close_CNN_2_relu-100-0.00023.hdf5')
model.compile(loss='mse', optimizer='adam')

# %% [markdown]
# Then, we need to invert-scaled the predicted data, which ranges from [0,1] because of the MinMaxScaler used previously.

# %%
predicted = model.predict(validation_datas)
predicted_inverted = []

for i in range(original_datas.shape[1]):
    scaler.fit(original_datas[:,i].reshape(-1,1))
    predicted_inverted.append(scaler.inverse_transform(predicted[:,:,i]))
print(np.array(predicted_inverted).shape)
#get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %% [markdown]
# Both Dataframes for the ground true (actual price) and the predicted price of Ethereum are set up. For visualization purpose, the plotted figure only shows the data from April 2020 thereafter.

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times       value
# 0 2020-04-04 16:55:00  145.650391
# 1 2020-04-04 17:00:00  145.624527
# 2 2020-04-04 17:05:00  145.604416
# 3 2020-04-04 17:10:00  145.443726
# 4 2020-04-04 17:15:00  145.386551

# %% [markdown]
# Plot the figure with pyplot. Since the predicted price is on a 16 minute basis, not linking all of them up would allow us to view the result easier. As a result, here the predicted data is plotted as red dot, as “ro” in the third line indicates. The blue line in the below graph represents the ground true (actual data), whereas the red dots represent the predicted Ethereum price.

# %%
prediction_df = prediction_df.loc[(prediction_df["times"].dt.year >= 2020 )&(prediction_df["times"].dt.month >= 1 ),: ]
ground_true_df = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020 )&(ground_true_df["times"].dt.month >= 1 ),:]

plt.figure(figsize=(20,10))
plt.plot(ground_true_df.times,ground_true_df.value, label = 'Actual')
plt.plot(prediction_df.times,prediction_df.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/ethereum2016to2021_close_CNN_2_relu_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 1103.5146863161242
