# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU, PReLU
from keras.utils import np_utils
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))
# print(tf.config.list_physical_devices('GPU'))

with h5py.File(''.join(['monero2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

output_file_name='monero2016to2021_close_CNN_2_relu'

# Set Hyperparameters
step_size = datas.shape[1]
batch_size= 128
nb_features = datas.shape[2]
epochs = 100

# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:]
# Build model

# 2 layers
model = Sequential()
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=16, kernel_size=32))
model.add(Dropout(0.5))
model.add(Conv1D(strides=3, filters=nb_features, kernel_size=28))

'''
# 3 Layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=8))
# 4 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=2))
'''

model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels,verbose=1, batch_size=batch_size,validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights_CNN/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 00001: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-01-0.00970.hdf5
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0475 - val_loss: 0.0097
# Epoch 2/100
#  5/13 [==========>...................] - ETA: 0s - loss: 0.0090
# Epoch 00002: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-02-0.00024.hdf5
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 2.4079e-04
# Epoch 3/100
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0072
# Epoch 00003: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-03-0.00039.hdf5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0070 - val_loss: 3.9474e-04
# Epoch 4/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00004: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-04-0.00036.hdf5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0045 - val_loss: 3.5863e-04
# Epoch 5/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0036
# Epoch 00005: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-05-0.00054.hdf5
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 5.3506e-04
# Epoch 6/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00006: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-06-0.00038.hdf5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0030 - val_loss: 3.7644e-04
# Epoch 7/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00007: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-07-0.00021.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 2.0651e-04
# Epoch 8/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00008: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-08-0.00014.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0025 - val_loss: 1.4318e-04
# Epoch 9/100
#  9/13 [===================>..........] - ETA: 0s - loss: 0.0022
# Epoch 00009: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-09-0.00024.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0022 - val_loss: 2.4350e-04
# Epoch 10/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0021
# Epoch 00010: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-10-0.00048.hdf5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 4.8228e-04
# Epoch 11/100
#  9/13 [===================>..........] - ETA: 0s - loss: 0.0019
# Epoch 00011: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-11-0.00016.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0019 - val_loss: 1.5773e-04
# Epoch 12/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00012: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-12-0.00034.hdf5
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 3.4021e-04
# Epoch 13/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00013: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-13-0.00025.hdf5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0017 - val_loss: 2.4653e-04
# Epoch 14/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0020
# Epoch 00014: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-14-0.00042.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 4.1763e-04
# Epoch 15/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0018
# Epoch 00015: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-15-0.00032.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 3.2450e-04
# Epoch 16/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0016
# Epoch 00016: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-16-0.00019.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 1.9287e-04
# Epoch 17/100
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0013
# Epoch 00017: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-17-0.00018.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0014 - val_loss: 1.8066e-04
# Epoch 18/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0014
# Epoch 00018: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-18-0.00012.hdf5
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 1.1512e-04
# Epoch 19/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0014
# Epoch 00019: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-19-0.00019.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 1.8736e-04
# Epoch 20/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0013
# Epoch 00020: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-20-0.00010.hdf5
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 1.0322e-04
# Epoch 21/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 00021: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-21-0.00011.hdf5
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 1.1232e-04
# Epoch 22/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0012
# Epoch 00022: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-22-0.00045.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 4.5196e-04
# Epoch 23/100
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0013
# Epoch 00023: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-23-0.00011.hdf5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0012 - val_loss: 1.0677e-04
# Epoch 24/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00024: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-24-0.00014.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 1.3765e-04
# Epoch 25/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00025: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-25-0.00044.hdf5
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 4.3502e-04
# Epoch 26/100
#  9/13 [===================>..........] - ETA: 0s - loss: 0.0010
# Epoch 00026: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-26-0.00011.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 1.0821e-04
# Epoch 27/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0012
# Epoch 00027: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-27-0.00047.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 4.7219e-04
# Epoch 28/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00028: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-28-0.00013.hdf5
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 1.2711e-04
# Epoch 29/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0011
# Epoch 00029: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-29-0.00010.hdf5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 1.0469e-04
# Epoch 30/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00030: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-30-0.00012.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0011 - val_loss: 1.1761e-04
# Epoch 31/100
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 00031: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-31-0.00033.hdf5
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0010 - val_loss: 3.2820e-04
# Epoch 32/100
# 13/13 [==============================] - ETA: 0s - loss: 9.6941e-04
# Epoch 00032: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-32-0.00011.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 9.6941e-04 - val_loss: 1.0732e-04
# Epoch 33/100
# 12/13 [==========================>...] - ETA: 0s - loss: 9.8976e-04
# Epoch 00033: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-33-0.00028.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 9.8006e-04 - val_loss: 2.7805e-04
# Epoch 34/100
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0010
# Epoch 00034: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-34-0.00012.hdf5
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 1.1559e-04
# Epoch 35/100
# 11/13 [========================>.....] - ETA: 0s - loss: 8.8199e-04
# Epoch 00035: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-35-0.00012.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 8.8899e-04 - val_loss: 1.2372e-04
# Epoch 36/100
# 10/13 [======================>.......] - ETA: 0s - loss: 9.5455e-04
# Epoch 00036: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-36-0.00010.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 9.4251e-04 - val_loss: 1.0227e-04
# Epoch 37/100
# 13/13 [==============================] - ETA: 0s - loss: 8.9865e-04
# Epoch 00037: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-37-0.00010.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 8.9865e-04 - val_loss: 1.0303e-04
# Epoch 38/100
# 13/13 [==============================] - ETA: 0s - loss: 9.4972e-04
# Epoch 00038: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-38-0.00022.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 9.4972e-04 - val_loss: 2.2312e-04
# Epoch 39/100
# 13/13 [==============================] - ETA: 0s - loss: 8.9148e-04
# Epoch 00039: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-39-0.00013.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 8.9148e-04 - val_loss: 1.2570e-04
# Epoch 40/100
# 10/13 [======================>.......] - ETA: 0s - loss: 8.6129e-04
# Epoch 00040: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-40-0.00010.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 9.2376e-04 - val_loss: 1.0370e-04
# Epoch 41/100
# 11/13 [========================>.....] - ETA: 0s - loss: 8.4772e-04
# Epoch 00041: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-41-0.00026.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 8.2377e-04 - val_loss: 2.5635e-04
# Epoch 42/100
# 11/13 [========================>.....] - ETA: 0s - loss: 7.5738e-04
# Epoch 00042: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-42-0.00011.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 7.8817e-04 - val_loss: 1.1011e-04
# Epoch 43/100
# 12/13 [==========================>...] - ETA: 0s - loss: 8.0875e-04
# Epoch 00043: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-43-0.00034.hdf5
# 13/13 [==============================] - 0s 16ms/step - loss: 8.0643e-04 - val_loss: 3.3596e-04
# Epoch 44/100
# 13/13 [==============================] - ETA: 0s - loss: 9.4094e-04
# Epoch 00044: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-44-0.00010.hdf5
# 13/13 [==============================] - 0s 11ms/step - loss: 9.4094e-04 - val_loss: 9.8704e-05
# Epoch 45/100
# 13/13 [==============================] - ETA: 0s - loss: 7.8231e-04
# Epoch 00045: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-45-0.00015.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 7.8231e-04 - val_loss: 1.4564e-04
# Epoch 46/100
# 13/13 [==============================] - ETA: 0s - loss: 8.6505e-04
# Epoch 00046: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-46-0.00012.hdf5
# 13/13 [==============================] - 0s 21ms/step - loss: 8.6505e-04 - val_loss: 1.2053e-04
# Epoch 47/100
# 13/13 [==============================] - ETA: 0s - loss: 8.8687e-04
# Epoch 00047: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu
saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-79-0.00011.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 6.4605e-04 - val_loss: 1.0866e-04
# Epoch 80/100
# 13/13 [==============================] - ETA: 0s - loss: 6.4208e-04
# Epoch 00080: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-80-0.00027.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 6.4208e-04 - val_loss: 2.6800e-04
# Epoch 81/100
# 13/13 [==============================] - ETA: 0s - loss: 6.7277e-04
# Epoch 00081: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-81-0.00010.hdf5
# 13/13 [==============================] - 0s 20ms/step - loss: 6.7277e-04 - val_loss: 1.0031e-04
# Epoch 82/100
# 10/13 [======================>.......] - ETA: 0s - loss: 7.9653e-04
# Epoch 00082: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-82-0.00050.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 7.5565e-04 - val_loss: 4.9928e-04
# Epoch 83/100
# 10/13 [======================>.......] - ETA: 0s - loss: 8.2829e-04
# Epoch 00083: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-83-0.00027.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 8.0573e-04 - val_loss: 2.6616e-04
# Epoch 84/100
# 10/13 [======================>.......] - ETA: 0s - loss: 8.2225e-04
# Epoch 00084: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-84-0.00047.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 8.1801e-04 - val_loss: 4.6583e-04
# Epoch 85/100
#  9/13 [===================>..........] - ETA: 0s - loss: 8.2271e-04
# Epoch 00085: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-85-0.00013.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 8.0587e-04 - val_loss: 1.3359e-04
# Epoch 86/100
# 13/13 [==============================] - ETA: 0s - loss: 7.4434e-04
# Epoch 00086: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-86-0.00017.hdf5
# 13/13 [==============================] - 0s 26ms/step - loss: 7.4434e-04 - val_loss: 1.7198e-04
# Epoch 87/100
# 13/13 [==============================] - ETA: 0s - loss: 6.4970e-04
# Epoch 00087: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-87-0.00014.hdf5
# 13/13 [==============================] - 0s 23ms/step - loss: 6.4970e-04 - val_loss: 1.4049e-04
# Epoch 88/100
# 13/13 [==============================] - ETA: 0s - loss: 7.0864e-04
# Epoch 00088: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-88-0.00067.hdf5
# 13/13 [==============================] - 0s 26ms/step - loss: 7.0864e-04 - val_loss: 6.6830e-04
# Epoch 89/100
# 11/13 [========================>.....] - ETA: 0s - loss: 6.4163e-04
# Epoch 00089: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-89-0.00011.hdf5
# 13/13 [==============================] - 0s 18ms/step - loss: 6.5144e-04 - val_loss: 1.1217e-04
# Epoch 90/100
# 13/13 [==============================] - ETA: 0s - loss: 6.1194e-04
# Epoch 00090: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-90-0.00019.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 6.1194e-04 - val_loss: 1.9295e-04
# Epoch 91/100
# 11/13 [========================>.....] - ETA: 0s - loss: 6.7063e-04
# Epoch 00091: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-91-0.00013.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 6.5634e-04 - val_loss: 1.3146e-04
# Epoch 92/100
# 11/13 [========================>.....] - ETA: 0s - loss: 6.6855e-04
# Epoch 00092: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-92-0.00016.hdf5
# 13/13 [==============================] - 0s 25ms/step - loss: 6.5622e-04 - val_loss: 1.6439e-04
# Epoch 93/100
#  9/13 [===================>..........] - ETA: 0s - loss: 7.0936e-04
# Epoch 00093: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-93-0.00014.hdf5
# 13/13 [==============================] - 0s 17ms/step - loss: 7.1606e-04 - val_loss: 1.3693e-04
# Epoch 94/100
# 13/13 [==============================] - ETA: 0s - loss: 6.7643e-04
# Epoch 00094: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-94-0.00023.hdf5
# 13/13 [==============================] - 0s 23ms/step - loss: 6.7643e-04 - val_loss: 2.2635e-04
# Epoch 95/100
# 13/13 [==============================] - ETA: 0s - loss: 6.8362e-04
# Epoch 00095: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-95-0.00019.hdf5
# 13/13 [==============================] - 0s 20ms/step - loss: 6.8362e-04 - val_loss: 1.8809e-04
# Epoch 96/100
# 13/13 [==============================] - ETA: 0s - loss: 6.5614e-04
# Epoch 00096: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-96-0.00028.hdf5
# 13/13 [==============================] - 0s 19ms/step - loss: 6.5614e-04 - val_loss: 2.7999e-04
# Epoch 97/100
# 13/13 [==============================] - ETA: 0s - loss: 6.4065e-04
# Epoch 00097: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-97-0.00010.hdf5
# 13/13 [==============================] - 0s 20ms/step - loss: 6.4065e-04 - val_loss: 1.0312e-04
# Epoch 98/100
# 11/13 [========================>.....] - ETA: 0s - loss: 6.3112e-04
# Epoch 00098: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-98-0.00015.hdf5
# 13/13 [==============================] - 0s 23ms/step - loss: 6.4845e-04 - val_loss: 1.4545e-04
# Epoch 99/100
# 13/13 [==============================] - ETA: 0s - loss: 5.6647e-04
# Epoch 00099: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-99-0.00010.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 5.6647e-04 - val_loss: 1.0122e-04
# Epoch 100/100
# 10/13 [======================>.......] - ETA: 0s - loss: 6.6461e-04
# Epoch 00100: saving model to weights_CNN/monero2016to2021_close_CNN_2_relu-100-0.00019.hdf5
# 13/13 [==============================] - 0s 24ms/step - loss: 6.7416e-04 - val_loss: 1.8765e-04

# %% [markdown]
# # Result Plotting

# %% [markdown]
# First, we need to reconstruct the model and load the trained_weights into the model.

# %%
from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
# import matplotlib
import matplotlib.pyplot as plt


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['monero2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

scaler=MinMaxScaler()
#split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,:]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,:]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)

# Set Hyperparameters
step_size = datas.shape[1]
batch_size= 128
nb_features = datas.shape[2]

# Build model
model = Sequential()
# 2 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=16, kernel_size=32))
# model.add(LeakyReLU())
model.add(Dropout(0.25))
model.add(Conv1D( strides=3, filters=nb_features, kernel_size=28))
model.load_weights('weights_CNN/monero2016to2021_close_CNN_2_relu-99-0.00010.hdf5')
model.compile(loss='mse', optimizer='adam')

# %% [markdown]
# Then, we need to invert-scaled the predicted data, which ranges from [0,1] because of the MinMaxScaler used previously.

# %%
predicted = model.predict(validation_datas)
predicted_inverted = []

for i in range(original_datas.shape[1]):
    scaler.fit(original_datas[:,i].reshape(-1,1))
    predicted_inverted.append(scaler.inverse_transform(predicted[:,:,i]))
print(np.array(predicted_inverted).shape)
# Get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# Since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %% [markdown]
# Both Dataframes for the ground true (actual price) and the predicted price of Monero are set up. For visualization purpose, the plotted figure only shows the data from April 2020 thereafter.

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times      value
# 0 2020-04-04 18:10:00  52.876392
# 1 2020-04-04 18:15:00  52.818779
# 2 2020-04-04 18:20:00  52.793129
# 3 2020-04-04 18:25:00  52.822342
# 4 2020-04-04 18:30:00  52.908192

# %% [markdown]
# Plot the figure with pyplot. Since the predicted price is on a 16 minute basis, not linking all of them up would allow us to view the result easier. As a result, here the predicted data is plotted as red dot, as “ro” in the third line indicates. The blue line in the below graph represents the ground true (actual data), whereas the red dots represent the predicted Monero price.

# %%
prediction_df = prediction_df.loc[(prediction_df["times"].dt.year >= 2020 )&(prediction_df["times"].dt.month >= 1 ),: ]
ground_true_df = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020 )&(ground_true_df["times"].dt.month >= 1 ),:]

plt.figure(figsize=(20,10))
plt.plot(ground_true_df.times,ground_true_df.value, label = 'Actual')
plt.plot(prediction_df.times,prediction_df.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/monero2016to2021_close_CNN_2_relu_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 22.77810396701719
