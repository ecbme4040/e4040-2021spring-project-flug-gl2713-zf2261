# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,Reshape
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras.utils import np_utils
from keras.layers import GRU
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

with h5py.File(''.join(['monero2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

output_file_name='monero2016to2021_close_GRU_1_tanh_relu_'

# Set Hyperparameters
step_size = datas.shape[1]
units= 512
batch_size = 256
nb_features = datas.shape[2]
epochs = 100
output_size = 16
# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:,0]

# Build model
model = Sequential()
model.add(GRU(units=units, input_shape=(step_size,nb_features), return_sequences=False))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(output_size))
model.add(Activation('relu'))
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, batch_size=batch_size,validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights_GRU/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0373
# Epoch 00001: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-01-0.00690.hdf5
# 7/7 [==============================] - 2s 290ms/step - loss: 0.0373 - val_loss: 0.0069
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 00002: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-02-0.00152.hdf5
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0063 - val_loss: 0.0015
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00003: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-03-0.00175.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00004: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-04-0.00041.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0020 - val_loss: 4.0690e-04
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00005: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-05-0.00021.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0015 - val_loss: 2.0516e-04
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 00006: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-06-0.00016.hdf5
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0012 - val_loss: 1.5547e-04
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0010
# Epoch 00007: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-07-0.00023.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0010 - val_loss: 2.2899e-04
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 8.8300e-04
# Epoch 00008: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-08-0.00004.hdf5
# 7/7 [==============================] - 2s 237ms/step - loss: 8.8300e-04 - val_loss: 4.3130e-05
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 8.7824e-04
# Epoch 00009: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-09-0.00008.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 8.7824e-04 - val_loss: 8.0578e-05
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 8.1061e-04
# Epoch 00010: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-10-0.00006.hdf5
# 7/7 [==============================] - 2s 236ms/step - loss: 8.1061e-04 - val_loss: 5.6119e-05
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 7.9709e-04
# Epoch 00011: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-11-0.00015.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 7.9709e-04 - val_loss: 1.4946e-04
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 7.6066e-04
# Epoch 00012: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-12-0.00009.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 7.6066e-04 - val_loss: 8.6296e-05
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 7.1691e-04
# Epoch 00013: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-13-0.00004.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 7.1691e-04 - val_loss: 3.9982e-05
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 6.9002e-04
# Epoch 00014: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-14-0.00002.hdf5
# 7/7 [==============================] - 2s 236ms/step - loss: 6.9002e-04 - val_loss: 2.1831e-05
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 6.6112e-04
# Epoch 00015: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-15-0.00002.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 6.6112e-04 - val_loss: 2.2767e-05
# Epoch 16/100
# 7/7 [==============================] - ETA: 0s - loss: 6.4183e-04
# Epoch 00016: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-16-0.00003.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 6.4183e-04 - val_loss: 2.7880e-05
# Epoch 17/100
# 7/7 [==============================] - ETA: 0s - loss: 6.4526e-04
# Epoch 00017: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-17-0.00009.hdf5
# 7/7 [==============================] - 2s 232ms/step - loss: 6.4526e-04 - val_loss: 8.9366e-05
# Epoch 18/100
# 7/7 [==============================] - ETA: 0s - loss: 6.3680e-04
# Epoch 00018: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-18-0.00007.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 6.3680e-04 - val_loss: 6.6217e-05
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 6.2123e-04
# Epoch 00019: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-19-0.00008.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 6.2123e-04 - val_loss: 7.7675e-05
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 6.4677e-04
# Epoch 00020: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-20-0.00003.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 6.4677e-04 - val_loss: 2.5644e-05
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 5.3541e-04
# Epoch 00021: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-21-0.00007.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 5.3541e-04 - val_loss: 6.7698e-05
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 5.9834e-04
# Epoch 00022: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-22-0.00002.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 5.9834e-04 - val_loss: 2.0125e-05
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 5.3086e-04
# Epoch 00023: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-23-0.00002.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 5.3086e-04 - val_loss: 1.5619e-05
# Epoch 24/100
# 7/7 [==============================] - ETA: 0s - loss: 5.1356e-04
# Epoch 00024: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-24-0.00002.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 5.1356e-04 - val_loss: 2.3626e-05
# Epoch 25/100
# 7/7 [==============================] - ETA: 0s - loss: 5.2039e-04
# Epoch 00025: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-25-0.00001.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 5.2039e-04 - val_loss: 1.2767e-05
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 5.2197e-04
# Epoch 00026: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-26-0.00003.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 5.2197e-04 - val_loss: 2.6424e-05
# Epoch 27/100
# 7/7 [==============================] - ETA: 0s - loss: 5.1090e-04
# Epoch 00027: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-27-0.00007.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss:
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6392e-04
# Epoch 00091: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-91-0.00001.hdf5
# 7/7 [==============================] - 2s 231ms/step - loss: 2.6392e-04 - val_loss: 1.3093e-05
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3872e-04
# Epoch 00092: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-92-0.00010.hdf5
# 7/7 [==============================] - 2s 234ms/step - loss: 2.3872e-04 - val_loss: 1.0135e-04
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 2.4044e-04
# Epoch 00093: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-93-0.00008.hdf5
# 7/7 [==============================] - 2s 229ms/step - loss: 2.4044e-04 - val_loss: 7.7054e-05
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 2.4075e-04
# Epoch 00094: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-94-0.00002.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 2.4075e-04 - val_loss: 2.0732e-05
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 2.2710e-04
# Epoch 00095: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-95-0.00002.hdf5
# 7/7 [==============================] - 2s 235ms/step - loss: 2.2710e-04 - val_loss: 2.1710e-05
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 2.2223e-04
# Epoch 00096: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-96-0.00003.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 2.2223e-04 - val_loss: 2.5873e-05
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 2.4356e-04
# Epoch 00097: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-97-0.00010.hdf5
# 7/7 [==============================] - 2s 233ms/step - loss: 2.4356e-04 - val_loss: 1.0402e-04
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3767e-04
# Epoch 00098: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-98-0.00001.hdf5
# 7/7 [==============================] - 2s 231ms/step - loss: 2.3767e-04 - val_loss: 1.4467e-05
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6637e-04
# Epoch 00099: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-99-0.00007.hdf5
# 7/7 [==============================] - 2s 230ms/step - loss: 2.6637e-04 - val_loss: 7.3186e-05
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3956e-04
# Epoch 00100: saving model to weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-100-0.00001.hdf5
# 7/7 [==============================] - 2s 232ms/step - loss: 2.3956e-04 - val_loss: 1.3223e-05

# %% [markdown]
# # Result Plotting

# %%
### from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import GRU
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
from tensorflow.compat.v1 import ConfigProto, Session
# import matplotlib
import matplotlib.pyplot as plt


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['monero2016to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

scaler=MinMaxScaler()
# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,0]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true.shape

ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)
ground_true_times.shape

# Set Hyperparameters
step_size = datas.shape[1]
batch_size = 256
nb_features = datas.shape[2]
epochs = 1
output_size = 16
units = 512
# second_units = 256

model = Sequential()
model.add(GRU(units=units, activation='tanh', input_shape=(step_size,nb_features), return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(output_size))
model.add(Activation('relu'))
model.load_weights('weights_GRU/monero2016to2021_close_GRU_1_tanh_relu_-100-0.00001.hdf5')
model.compile(loss='mse', optimizer='adam')

original_datas.shape

predicted = model.predict(validation_datas)
predicted_inverted = []

# In[7]:
# we only care about the 0 axis, close price data

scaler.fit(original_datas[:,0].reshape(-1,1))
predicted_inverted.append(scaler.inverse_transform(predicted))
print(np.array(predicted_inverted).shape)
#get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.set_index('times').reset_index()
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times      value
# 0 2020-04-04 18:10:00  54.825672
# 1 2020-04-04 18:15:00  55.419010
# 2 2020-04-04 18:20:00  54.640598
# 3 2020-04-04 18:25:00  54.106781
# 4 2020-04-04 18:30:00  54.824314

# %%
prediction_df_load = prediction_df.loc[(prediction_df["times"].dt.year >= 2020)&(prediction_df["times"].dt.month >= 1),:]
# 
ground_true_df_load = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020)&(ground_true_df["times"].dt.month >= 1),:]
# 

plt.figure(figsize=(20,10))
plt.plot(ground_true_df_load.times,ground_true_df_load.value, label = 'Actual')
plt.plot(prediction_df_load.times,prediction_df_load.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/monero2016to2021_close_GRU_1_tanh_relu_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 2.9886203136647866
