# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU, PReLU
from keras.utils import np_utils
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))
# print(tf.config.list_physical_devices('GPU'))

with h5py.File(''.join(['bitcoin2015to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

output_file_name='bitcoin2015to2021_close_CNN_2_relu'

# Set Hyperparameters
step_size = datas.shape[1]
batch_size= 128
nb_features = datas.shape[2]
epochs = 100

# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:]

# Build model
# 2 layers
model = Sequential()
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=16, kernel_size=32))
model.add(Dropout(0.5))
model.add(Conv1D(strides=3, filters=nb_features, kernel_size=28))

'''
# 3 Layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=8))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=8))
# 4 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D(activation='relu', strides=2, filters=8, kernel_size=2))
#model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(Conv1D( strides=2, filters=nb_features, kernel_size=2))
'''

model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels,verbose=1, batch_size=batch_size,validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights_CNN/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
#  1/13 [=>............................] - ETA: 0s - loss: 0.0101
# Epoch 00001: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-01-0.00067.hdf5
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0029 - val_loss: 6.6551e-04
# Epoch 2/100
#  1/13 [=>............................] - ETA: 0s - loss: 7.1267e-04
# Epoch 00002: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-02-0.00255.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 7.7031e-04 - val_loss: 0.0025
# Epoch 3/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.6244e-04
# Epoch 00003: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-03-0.00080.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 5.2846e-04 - val_loss: 8.0284e-04
# Epoch 4/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.5363e-04
# Epoch 00004: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-04-0.00018.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 4.2609e-04 - val_loss: 1.7772e-04
# Epoch 5/100
#  1/13 [=>............................] - ETA: 0s - loss: 4.0969e-04
# Epoch 00005: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-05-0.00038.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.7225e-04 - val_loss: 3.8363e-04
# Epoch 6/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.9148e-04
# Epoch 00006: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-06-0.00039.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 3.3572e-04 - val_loss: 3.9188e-04
# Epoch 7/100
#  1/13 [=>............................] - ETA: 0s - loss: 3.1606e-04
# Epoch 00007: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-07-0.00020.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.9171e-04 - val_loss: 2.0194e-04
# Epoch 8/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.4208e-04
# Epoch 00008: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-08-0.00019.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.7295e-04 - val_loss: 1.8700e-04
# Epoch 9/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.4518e-04
# Epoch 00009: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-09-0.00018.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.5099e-04 - val_loss: 1.8150e-04
# Epoch 10/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.1183e-04
# Epoch 00010: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-10-0.00018.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.3348e-04 - val_loss: 1.8422e-04
# Epoch 11/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.7528e-04
# Epoch 00011: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-11-0.00026.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.3259e-04 - val_loss: 2.5649e-04
# Epoch 12/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.6459e-04
# Epoch 00012: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-12-0.00020.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.1762e-04 - val_loss: 1.9864e-04
# Epoch 13/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.9764e-04
# Epoch 00013: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-13-0.00020.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.0412e-04 - val_loss: 1.9632e-04
# Epoch 14/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.0291e-04
# Epoch 00014: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-14-0.00022.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 2.0066e-04 - val_loss: 2.1906e-04
# Epoch 15/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.9655e-04
# Epoch 00015: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-15-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.8964e-04 - val_loss: 1.6961e-04
# Epoch 16/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.8235e-04
# Epoch 00016: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-16-0.00018.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.9125e-04 - val_loss: 1.7938e-04
# Epoch 17/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.7489e-04
# Epoch 00017: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-17-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.8856e-04 - val_loss: 1.6666e-04
# Epoch 18/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.1642e-04
# Epoch 00018: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-18-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.7885e-04 - val_loss: 1.6535e-04
# Epoch 19/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.0332e-04
# Epoch 00019: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-19-0.00023.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.7627e-04 - val_loss: 2.2982e-04
# Epoch 20/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.6896e-04
# Epoch 00020: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-20-0.00016.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 1.6535e-04 - val_loss: 1.6338e-04
# Epoch 21/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.7300e-04
# Epoch 00021: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-21-0.00036.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.7100e-04 - val_loss: 3.6245e-04
# Epoch 22/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.7298e-04
# Epoch 00022: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-22-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5864e-04 - val_loss: 1.6727e-04
# Epoch 23/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.4690e-04
# Epoch 00023: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-23-0.00016.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5612e-04 - val_loss: 1.6178e-04
# Epoch 24/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.3789e-04
# Epoch 00024: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-24-0.00018.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5758e-04 - val_loss: 1.7881e-04
# Epoch 25/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.3755e-04
# Epoch 00025: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-25-0.00040.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5716e-04 - val_loss: 4.0199e-04
# Epoch 26/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.5419e-04
# Epoch 00026: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-26-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.4957e-04 - val_loss: 1.7100e-04
# Epoch 27/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.2614e-04
# Epoch 00027: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-27-0.00019.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.
100
#  1/13 [=>............................] - ETA: 0s - loss: 1.2523e-04
# Epoch 00089: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-89-0.00028.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 9.9091e-05 - val_loss: 2.7846e-04
# Epoch 90/100
#  1/13 [=>............................] - ETA: 0s - loss: 7.9323e-05
# Epoch 00090: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-90-0.00129.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0520e-04 - val_loss: 0.0013
# Epoch 91/100
#  1/13 [=>............................] - ETA: 0s - loss: 2.1082e-04
# Epoch 00091: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-91-0.00018.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.3366e-04 - val_loss: 1.8449e-04
# Epoch 92/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.1286e-04
# Epoch 00092: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-92-0.00029.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0871e-04 - val_loss: 2.8745e-04
# Epoch 93/100
#  1/13 [=>............................] - ETA: 0s - loss: 8.6267e-05
# Epoch 00093: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-93-0.00018.hdf5
# 13/13 [==============================] - 0s 8ms/step - loss: 1.0143e-04 - val_loss: 1.8393e-04
# Epoch 94/100
#  1/13 [=>............................] - ETA: 0s - loss: 8.5967e-05
# Epoch 00094: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-94-0.00043.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 9.7813e-05 - val_loss: 4.3025e-04
# Epoch 95/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.1497e-04
# Epoch 00095: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-95-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0167e-04 - val_loss: 1.7259e-04
# Epoch 96/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.0462e-04
# Epoch 00096: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-96-0.00020.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0189e-04 - val_loss: 1.9589e-04
# Epoch 97/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.1294e-04
# Epoch 00097: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-97-0.00023.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 9.8986e-05 - val_loss: 2.2990e-04
# Epoch 98/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.0318e-04
# Epoch 00098: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-98-0.00017.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 9.5783e-05 - val_loss: 1.7109e-04
# Epoch 99/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.2301e-04
# Epoch 00099: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-99-0.00016.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0184e-04 - val_loss: 1.5863e-04
# Epoch 100/100
#  1/13 [=>............................] - ETA: 0s - loss: 9.7649e-05
# Epoch 00100: saving model to weights_CNN/bitcoin2015to2021_close_CNN_2_relu-100-0.00041.hdf5
# 13/13 [==============================] - 0s 7ms/step - loss: 9.6446e-05 - val_loss: 4.0898e-04

# %% [markdown]
# # Result Plotting

# %% [markdown]
# First, we need to reconstruct the model and load the trained_weights into the model.

# %%
from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
# import matplotlib
import matplotlib.pyplot as plt


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['bitcoin2015to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

scaler=MinMaxScaler()
# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,:]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,:]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)
step_size = datas.shape[1]
batch_size= 128
nb_features = datas.shape[2]

model = Sequential()

# 2 layers
model.add(Conv1D(activation='relu', input_shape=(step_size, nb_features), strides=3, filters=16, kernel_size=32))
# model.add(LeakyReLU())
model.add(Dropout(0.25))
model.add(Conv1D( strides=3, filters=nb_features, kernel_size=28))
model.load_weights('weights_CNN/bitcoin2015to2021_close_CNN_2_relu-99-0.00016.hdf5')
model.compile(loss='mse', optimizer='adam')

# %% [markdown]
# Then, we need to invert-scaled the predicted data, which ranges from [0,1] because of the MinMaxScaler used previously.

# %%
predicted = model.predict(validation_datas)
predicted_inverted = []

for i in range(original_datas.shape[1]):
    scaler.fit(original_datas[:,i].reshape(-1,1))
    predicted_inverted.append(scaler.inverse_transform(predicted[:,:,i]))
print(np.array(predicted_inverted).shape)
# Get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# Since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %% [markdown]
# Both Dataframes for the ground true (actual price) and the predicted price of Bitcoin are set up. For visualization purpose, the plotted figure only shows the data from April 2020 thereafter.

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times        value
# 0 2020-04-04 16:50:00  6713.672852
# 1 2020-04-04 16:55:00  6715.625000
# 2 2020-04-04 17:00:00  6715.629883
# 3 2020-04-04 17:05:00  6708.966797
# 4 2020-04-04 17:10:00  6710.304688

# %% [markdown]
# Plot the figure with pyplot. Since the predicted price is on a 16 minute basis, not linking all of them up would allow us to view the result easier. As a result, here the predicted data is plotted as red dot, as “ro” in the third line indicates. The blue line in the below graph represents the ground true (actual data), whereas the red dots represent the predicted Bitcoin price.

# %%
prediction_df = prediction_df.loc[(prediction_df["times"].dt.year >= 2020 )&(prediction_df["times"].dt.month >= 1 ),: ]
ground_true_df = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020 )&(ground_true_df["times"].dt.month >= 1 ),:]

plt.figure(figsize=(20,10))
plt.plot(ground_true_df.times,ground_true_df.value, label = 'Actual')
plt.plot(prediction_df.times,prediction_df.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/bitcoin2015to2021_close_CNN_2_relu_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 595087.949744598
