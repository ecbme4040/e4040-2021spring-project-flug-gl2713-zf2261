# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,Reshape
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras.utils import np_utils
from keras.layers import GRU
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

with h5py.File(''.join(['bitcoin2015to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

output_file_name='bitcoin2015to2021_close_GRU_1_tanh_relu_'

# Set Hyperparameters
step_size = datas.shape[1]
units= 512
batch_size = 256
nb_features = datas.shape[2]
epochs = 100
output_size = 16

# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:,0]

# Build model
model = Sequential()
model.add(GRU(units=units, input_shape=(step_size,nb_features), return_sequences=False))
model.add(Activation('tanh'))
model.add(Dropout(0.5))
model.add(Dense(output_size))
model.add(Activation('relu'))
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, batch_size=batch_size,validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights_GRU/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 00001: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-01-0.04421.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 0.0052 - val_loss: 0.0442
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00002: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-02-0.00759.hdf5
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0017 - val_loss: 0.0076
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 6.4222e-04
# Epoch 00003: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-03-0.00612.hdf5
# 7/7 [==============================] - 2s 223ms/step - loss: 6.4222e-04 - val_loss: 0.0061
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 3.6628e-04
# Epoch 00004: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-04-0.00042.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 3.6628e-04 - val_loss: 4.1553e-04
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3335e-04
# Epoch 00005: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-05-0.00257.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 2.3335e-04 - val_loss: 0.0026
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 2.0457e-04
# Epoch 00006: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-06-0.00003.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 2.0457e-04 - val_loss: 2.7788e-05
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7879e-04
# Epoch 00007: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-07-0.00055.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 1.7879e-04 - val_loss: 5.5182e-04
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6449e-04
# Epoch 00008: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-08-0.00008.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 1.6449e-04 - val_loss: 7.5548e-05
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6111e-04
# Epoch 00009: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-09-0.00003.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 1.6111e-04 - val_loss: 2.5262e-05
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4826e-04
# Epoch 00010: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-10-0.00006.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 1.4826e-04 - val_loss: 6.4807e-05
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4579e-04
# Epoch 00011: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-11-0.00019.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 1.4579e-04 - val_loss: 1.8715e-04
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2715e-04
# Epoch 00012: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-12-0.00023.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 1.2715e-04 - val_loss: 2.2895e-04
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2742e-04
# Epoch 00013: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-13-0.00003.hdf5
# 7/7 [==============================] - 2s 227ms/step - loss: 1.2742e-04 - val_loss: 2.7624e-05
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1379e-04
# Epoch 00014: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-14-0.00006.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 1.1379e-04 - val_loss: 6.0038e-05
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0966e-04
# Epoch 00015: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-15-0.00003.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 1.0966e-04 - val_loss: 2.5091e-05
# Epoch 16/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0618e-04
# Epoch 00016: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-16-0.00002.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 1.0618e-04 - val_loss: 1.8937e-05
# Epoch 17/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0874e-04
# Epoch 00017: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-17-0.00004.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 1.0874e-04 - val_loss: 3.7783e-05
# Epoch 18/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0390e-04
# Epoch 00018: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-18-0.00006.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 1.0390e-04 - val_loss: 5.7947e-05
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 9.8688e-05
# Epoch 00019: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-19-0.00002.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 9.8688e-05 - val_loss: 1.7096e-05
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 9.4444e-05
# Epoch 00020: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-20-0.00002.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 9.4444e-05 - val_loss: 2.3940e-05
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 9.6094e-05
# Epoch 00021: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-21-0.00003.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 9.6094e-05 - val_loss: 2.7577e-05
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 8.8179e-05
# Epoch 00022: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-22-0.00014.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 8.8179e-05 - val_loss: 1.3861e-04
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 8.9181e-05
# Epoch 00023: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-23-0.00013.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 8.9181e-05 - val_loss: 1.3321e-04
# Epoch 24/100
# 7/7 [==============================] - ETA: 0s - loss: 9.1279e-05
# Epoch 00024: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-24-0.00003.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 9.1279e-05 - val_loss: 3.2676e-05
# Epoch 25/100
# 7/7 [==============================] - ETA: 0s - loss: 8.4019e-05
# Epoch 00025: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-25-0.00001.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 8.4019e-05 - val_loss: 1.3836e-05
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 7.6624e-05
# Epoch 00026: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-26-0.00004.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 7.6624e-05 - val_loss: 3.5102e-05
# Epoch 27/100
# 7/7 [==============================] - ETA: 0s - loss: 7.5485e-05
# Epoch 00027: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-27-0.00005.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss:
# Epoch 89/100
# 7/7 [==============================] - ETA: 0s - loss: 2.9685e-05
# Epoch 00089: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-89-0.00003.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 2.9685e-05 - val_loss: 2.5048e-05
# Epoch 90/100
# 7/7 [==============================] - ETA: 0s - loss: 2.8503e-05
# Epoch 00090: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-90-0.00004.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 2.8503e-05 - val_loss: 3.9021e-05
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 3.2957e-05
# Epoch 00091: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-91-0.00001.hdf5
# 7/7 [==============================] - 2s 223ms/step - loss: 3.2957e-05 - val_loss: 1.4860e-05
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6737e-05
# Epoch 00092: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-92-0.00001.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 2.6737e-05 - val_loss: 1.3864e-05
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 2.7932e-05
# Epoch 00093: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-93-0.00001.hdf5
# 7/7 [==============================] - 2s 227ms/step - loss: 2.7932e-05 - val_loss: 1.2999e-05
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6353e-05
# Epoch 00094: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-94-0.00001.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 2.6353e-05 - val_loss: 1.2835e-05
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 2.5449e-05
# Epoch 00095: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-95-0.00004.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 2.5449e-05 - val_loss: 3.6738e-05
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 2.7438e-05
# Epoch 00096: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-96-0.00006.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 2.7438e-05 - val_loss: 5.9590e-05
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 3.0939e-05
# Epoch 00097: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-97-0.00004.hdf5
# 7/7 [==============================] - 2s 224ms/step - loss: 3.0939e-05 - val_loss: 3.8136e-05
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 2.7293e-05
# Epoch 00098: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-98-0.00003.hdf5
# 7/7 [==============================] - 2s 225ms/step - loss: 2.7293e-05 - val_loss: 3.1265e-05
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6431e-05
# Epoch 00099: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-99-0.00001.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 2.6431e-05 - val_loss: 1.3517e-05
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 2.6312e-05
# Epoch 00100: saving model to weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-100-0.00001.hdf5
# 7/7 [==============================] - 2s 226ms/step - loss: 2.6312e-05 - val_loss: 1.2113e-05

# %% [markdown]
# # Result Plotting

# %%
### from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import GRU
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
from tensorflow.compat.v1 import ConfigProto, Session
# import matplotlib
import matplotlib.pyplot as plt


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['bitcoin2015to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

scaler=MinMaxScaler()

# Split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,0]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true.shape

ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)
ground_true_times.shape

step_size = datas.shape[1]
batch_size = 256
nb_features = datas.shape[2]
epochs = 1
output_size = 16
units = 512

# Build model
model = Sequential()
model.add(GRU(units=units, activation='tanh', input_shape=(step_size,nb_features), return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(output_size))
model.add(Activation('relu'))
model.load_weights('weights_GRU/bitcoin2015to2021_close_GRU_1_tanh_relu_-100-0.00001.hdf5')
model.compile(loss='mse', optimizer='adam')

original_datas.shape

predicted = model.predict(validation_datas)
predicted_inverted = []

# we only care about the 0 axis, close price data

scaler.fit(original_datas[:,0].reshape(-1,1))
predicted_inverted.append(scaler.inverse_transform(predicted))
print(np.array(predicted_inverted).shape)
#get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.set_index('times').reset_index()
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times        value
# 0 2020-04-04 16:50:00  6827.655273
# 1 2020-04-04 16:55:00  6840.824707
# 2 2020-04-04 17:00:00  6833.311523
# 3 2020-04-04 17:05:00  6818.825684
# 4 2020-04-04 17:10:00  6831.033691

# %%
prediction_df_load = prediction_df.loc[(prediction_df["times"].dt.year >= 2020)&(prediction_df["times"].dt.month >= 1),:]
# 
ground_true_df_load = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020)&(ground_true_df["times"].dt.month >= 1),:]
# 

plt.figure(figsize=(20,10))
plt.plot(ground_true_df_load.times,ground_true_df_load.value, label = 'Actual')
plt.plot(prediction_df_load.times,prediction_df_load.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/bitcoin2015to2021_close_GRU_1_tanh_relu_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 46026.130519565406
