# %% [markdown]
# LSTM is relatively easier than CNN to implement as we hardly need to care about the relationship among kernel size, strides, input size and output size. Just make sure the dimension of input and output is defined correctly in the network.

# %%
import pandas as pd
import numpy as numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,Reshape
from keras.layers import Conv1D, MaxPooling1D
from keras.utils import np_utils
from keras.layers import LSTM, LeakyReLU
from keras.callbacks import CSVLogger, ModelCheckpoint
import h5py
import os
import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session
from tensorflow.compat.v1 import ConfigProto, Session
from tensorflow.python.client import device_lib


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

with h5py.File(''.join(['bitcoin2015to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]

# Set Hyperparameters
step_size = datas.shape[1]
units= 512
second_units = 256
batch_size = 256
nb_features = datas.shape[2]
epochs = 100
output_size=16
output_file_name='bitcoin2015to2021_close_LSTM_1_tanh_leaky_'

#split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:]
validation_labels = labels[training_size:,:,0]

#build model
model = Sequential()
model.add(LSTM(units=units,activation='tanh', input_shape=(step_size,nb_features),return_sequences=False))
model.add(Dropout(0.6))
model.add(Dense(output_size))
model.add(LeakyReLU())
model.compile(loss='mse', optimizer='adam')
model.fit(training_datas, training_labels, batch_size=batch_size, validation_data=(validation_datas,validation_labels), epochs = epochs, callbacks=[CSVLogger(output_file_name+'.csv', append=True),ModelCheckpoint('weights/'+output_file_name+'-{epoch:02d}-{val_loss:.5f}.hdf5', monitor='val_loss', verbose=1,mode='min')])
# Out:
# Epoch 1/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00001: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-01-0.07030.hdf5
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0049 - val_loss: 0.0703
# Epoch 2/100
# 7/7 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00002: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-02-0.03384.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0017 - val_loss: 0.0338
# Epoch 3/100
# 7/7 [==============================] - ETA: 0s - loss: 7.8117e-04
# Epoch 00003: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-03-0.00354.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 7.8117e-04 - val_loss: 0.0035
# Epoch 4/100
# 7/7 [==============================] - ETA: 0s - loss: 4.5292e-04
# Epoch 00004: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-04-0.00221.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 4.5292e-04 - val_loss: 0.0022
# Epoch 5/100
# 7/7 [==============================] - ETA: 0s - loss: 3.1914e-04
# Epoch 00005: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-05-0.00400.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 3.1914e-04 - val_loss: 0.0040
# Epoch 6/100
# 7/7 [==============================] - ETA: 0s - loss: 2.8868e-04
# Epoch 00006: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-06-0.00018.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 2.8868e-04 - val_loss: 1.7885e-04
# Epoch 7/100
# 7/7 [==============================] - ETA: 0s - loss: 2.3623e-04
# Epoch 00007: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-07-0.00025.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 2.3623e-04 - val_loss: 2.4911e-04
# Epoch 8/100
# 7/7 [==============================] - ETA: 0s - loss: 2.1644e-04
# Epoch 00008: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-08-0.00071.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 2.1644e-04 - val_loss: 7.0553e-04
# Epoch 9/100
# 7/7 [==============================] - ETA: 0s - loss: 1.8782e-04
# Epoch 00009: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-09-0.00142.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.8782e-04 - val_loss: 0.0014
# Epoch 10/100
# 7/7 [==============================] - ETA: 0s - loss: 1.7380e-04
# Epoch 00010: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-10-0.00057.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.7380e-04 - val_loss: 5.6737e-04
# Epoch 11/100
# 7/7 [==============================] - ETA: 0s - loss: 1.6566e-04
# Epoch 00011: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-11-0.00015.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.6566e-04 - val_loss: 1.4774e-04
# Epoch 12/100
# 7/7 [==============================] - ETA: 0s - loss: 1.5370e-04
# Epoch 00012: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-12-0.00011.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 1.5370e-04 - val_loss: 1.0814e-04
# Epoch 13/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4724e-04
# Epoch 00013: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-13-0.00013.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.4724e-04 - val_loss: 1.2687e-04
# Epoch 14/100
# 7/7 [==============================] - ETA: 0s - loss: 1.4230e-04
# Epoch 00014: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-14-0.00052.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.4230e-04 - val_loss: 5.1793e-04
# Epoch 15/100
# 7/7 [==============================] - ETA: 0s - loss: 1.3650e-04
# Epoch 00015: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-15-0.00047.hdf5
# 7/7 [==============================] - 2s 284ms/step - loss: 1.3650e-04 - val_loss: 4.6829e-04
# Epoch 16/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2914e-04
# Epoch 00016: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-16-0.00042.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.2914e-04 - val_loss: 4.1596e-04
# Epoch 17/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2460e-04
# Epoch 00017: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-17-0.00071.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.2460e-04 - val_loss: 7.0696e-04
# Epoch 18/100
# 7/7 [==============================] - ETA: 0s - loss: 1.2749e-04
# Epoch 00018: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-18-0.00033.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.2749e-04 - val_loss: 3.2802e-04
# Epoch 19/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1971e-04
# Epoch 00019: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-19-0.00010.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 1.1971e-04 - val_loss: 9.7227e-05
# Epoch 20/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1280e-04
# Epoch 00020: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-20-0.00006.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 1.1280e-04 - val_loss: 6.0133e-05
# Epoch 21/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1530e-04
# Epoch 00021: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-21-0.00009.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.1530e-04 - val_loss: 9.4096e-05
# Epoch 22/100
# 7/7 [==============================] - ETA: 0s - loss: 1.1270e-04
# Epoch 00022: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-22-0.00020.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 1.1270e-04 - val_loss: 2.0243e-04
# Epoch 23/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0631e-04
# Epoch 00023: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-23-0.00007.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.0631e-04 - val_loss: 6.7992e-05
# Epoch 24/100
# 7/7 [==============================] - ETA: 0s - loss: 1.0552e-04
# Epoch 00024: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-24-0.00013.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 1.0552e-04 - val_loss: 1.2685e-04
# Epoch 25/100
# 7/7 [==============================] - ETA: 0s - loss: 9.6460e-05
# Epoch 00025: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-25-0.00018.hdf5
# 7/7 [==============================] - 2s 283ms/step - loss: 9.6460e-05 - val_loss: 1.7635e-04
# Epoch 26/100
# 7/7 [==============================] - ETA: 0s - loss: 9.0080e-05
# Epoch 00026: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-26-0.00012.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 9.0080e-05 - val_loss: 1.1567e-04
# Epoch 27/100
# 7/7 [==============================] - ETA: 0s - loss:
hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 3.2805e-05 - val_loss: 3.8357e-05
# Epoch 89/100
# 7/7 [==============================] - ETA: 0s - loss: 3.3561e-05
# Epoch 00089: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-89-0.00030.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 3.3561e-05 - val_loss: 2.9523e-04
# Epoch 90/100
# 7/7 [==============================] - ETA: 0s - loss: 3.6936e-05
# Epoch 00090: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-90-0.00002.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 3.6936e-05 - val_loss: 1.8318e-05
# Epoch 91/100
# 7/7 [==============================] - ETA: 0s - loss: 3.6399e-05
# Epoch 00091: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-91-0.00011.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 3.6399e-05 - val_loss: 1.0802e-04
# Epoch 92/100
# 7/7 [==============================] - ETA: 0s - loss: 3.6049e-05
# Epoch 00092: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-92-0.00006.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 3.6049e-05 - val_loss: 6.3958e-05
# Epoch 93/100
# 7/7 [==============================] - ETA: 0s - loss: 3.3533e-05
# Epoch 00093: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-93-0.00015.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 3.3533e-05 - val_loss: 1.4531e-04
# Epoch 94/100
# 7/7 [==============================] - ETA: 0s - loss: 3.2577e-05
# Epoch 00094: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-94-0.00011.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 3.2577e-05 - val_loss: 1.1233e-04
# Epoch 95/100
# 7/7 [==============================] - ETA: 0s - loss: 3.3710e-05
# Epoch 00095: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-95-0.00009.hdf5
# 7/7 [==============================] - 2s 281ms/step - loss: 3.3710e-05 - val_loss: 9.1218e-05
# Epoch 96/100
# 7/7 [==============================] - ETA: 0s - loss: 3.3444e-05
# Epoch 00096: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-96-0.00017.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 3.3444e-05 - val_loss: 1.7395e-04
# Epoch 97/100
# 7/7 [==============================] - ETA: 0s - loss: 3.2393e-05
# Epoch 00097: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-97-0.00007.hdf5
# 7/7 [==============================] - 2s 279ms/step - loss: 3.2393e-05 - val_loss: 6.5574e-05
# Epoch 98/100
# 7/7 [==============================] - ETA: 0s - loss: 3.1581e-05
# Epoch 00098: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-98-0.00023.hdf5
# 7/7 [==============================] - 2s 282ms/step - loss: 3.1581e-05 - val_loss: 2.2891e-04
# Epoch 99/100
# 7/7 [==============================] - ETA: 0s - loss: 3.4066e-05
# Epoch 00099: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-99-0.00002.hdf5
# 7/7 [==============================] - 2s 279ms/step - loss: 3.4066e-05 - val_loss: 2.2641e-05
# Epoch 100/100
# 7/7 [==============================] - ETA: 0s - loss: 3.3036e-05
# Epoch 00100: saving model to weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-100-0.00005.hdf5
# 7/7 [==============================] - 2s 280ms/step - loss: 3.3036e-05 - val_loss: 4.5535e-05

# %% [markdown]
# # Result Plotting

# %%
### from keras import applications
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.callbacks import CSVLogger
import tensorflow as tf
from imageio import imread
import numpy as np
import random
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, LeakyReLU
from keras import backend as K
import keras
from keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.compat.v1.keras.backend import set_session
from keras import optimizers
import h5py
from sklearn.preprocessing import MinMaxScaler
import os
import pandas as pd
from tensorflow.compat.v1 import ConfigProto, Session
# import matplotlib
import matplotlib.pyplot as plt


# Configure GPU
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

with h5py.File(''.join(['bitcoin2015to2021_close.h5']), 'r') as hf:
    datas = hf['inputs'][()]
    labels = hf['outputs'][()]
    input_times = hf['input_times'][()]
    output_times = hf['output_times'][()]
    original_inputs = hf['original_inputs'][()]
    original_outputs = hf['original_outputs'][()]
    original_datas = hf['original_datas'][()]

config = ConfigProto()
config.gpu_options.allow_growth = True
set_session(Session(config=config))

scaler=MinMaxScaler()

# split training validation
training_size = int(0.8 * datas.shape[0])
training_datas = datas[:training_size,:,:]
training_labels = labels[:training_size,:,0]
validation_datas = datas[training_size:,:,:]
validation_labels = labels[training_size:,:,0]
validation_original_outputs = original_outputs[training_size:,:,:]
validation_original_inputs = original_inputs[training_size:,:,:]
validation_input_times = input_times[training_size:,:,:]
validation_output_times = output_times[training_size:,:,:]

ground_true = np.append(validation_original_inputs,validation_original_outputs, axis=1)
ground_true.shape

ground_true_times = np.append(validation_input_times,validation_output_times, axis=1)
ground_true_times.shape

step_size = datas.shape[1]
batch_size = 256
nb_features = datas.shape[2]
epochs = 1
output_size = 16
units = 512
second_units = 256

# Build model
model = Sequential()
model.add(LSTM(units=units,activation='tanh', input_shape=(step_size,nb_features),return_sequences=False))
# model.add(LSTM(units=second_units,activation='relu',return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(output_size))
model.add(LeakyReLU())
model.load_weights('weights/bitcoin2015to2021_close_LSTM_1_tanh_leaky_-99-0.00002.hdf5')
model.compile(loss='mse', optimizer='adam')

original_datas.shape

predicted = model.predict(validation_datas)
predicted_inverted = []

# In[7]:
# we only care about the 0 axis, close price data

scaler.fit(original_datas[:,0].reshape(-1,1))
predicted_inverted.append(scaler.inverse_transform(predicted))
print(np.array(predicted_inverted).shape)
# get only the close data
ground_true = ground_true[:,:,0].reshape(-1)
ground_true_times = ground_true_times.reshape(-1)
ground_true_times = pd.to_datetime(ground_true_times, unit='s')
# since we are appending in the first dimension
predicted_inverted = np.array(predicted_inverted)[0,:,:].reshape(-1)
print(np.array(predicted_inverted).shape)
validation_output_times = pd.to_datetime(validation_output_times.reshape(-1), unit='s')
# Out:
# (1, 395, 16)
# (6320,)

# %%
ground_true_df = pd.DataFrame()
ground_true_df['times'] = ground_true_times
ground_true_df['value'] = ground_true
ground_true_df.set_index('times').reset_index()
ground_true_df.shape
# Out:
# (107440, 2)

# %%
prediction_df = pd.DataFrame()
prediction_df['times'] = validation_output_times
prediction_df['value'] = predicted_inverted
prediction_df.shape
# Out:
# (6320, 2)

# %%
prediction_df.head()
# Out:
#                 times        value
# 0 2020-04-04 16:50:00  6871.521484
# 1 2020-04-04 16:55:00  6841.409668
# 2 2020-04-04 17:00:00  6881.524414
# 3 2020-04-04 17:05:00  6819.769531
# 4 2020-04-04 17:10:00  6853.113770

# %%
prediction_df_load = prediction_df.loc[(prediction_df["times"].dt.year >= 2020)&(prediction_df["times"].dt.month >= 1),:]
# 
ground_true_df_load = ground_true_df.loc[(ground_true_df["times"].dt.year >= 2020)&(ground_true_df["times"].dt.month >= 1),:]
# 

plt.figure(figsize=(20,10))
plt.plot(ground_true_df_load.times,ground_true_df_load.value, label = 'Actual')
# plt.plot(prediction_df.times,prediction_df.value, label = 'Predicted')
plt.plot(prediction_df_load.times,prediction_df_load.value,'ro', label='Predicted')
plt.legend(loc='upper left')
plt.savefig('result/bitcoin2015to2021_close_LSTM_1_tanh_leaky_result.png')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(validation_original_outputs[:,:,0].reshape(-1),predicted_inverted)
# Out:
# 84932.7231427368
